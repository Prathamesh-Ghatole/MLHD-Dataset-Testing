# %% [markdown]
# ### Import Lib

# %%
import pandas as pd
import os
import psycopg2
import numpy as np
import dask.dataframe as dd
import random
results = []
# import sqlalchemy as sql

# %% [markdown]
# ### Create Connection to PostgreSQL

# %%
# Create Connection to postgresql

conn = psycopg2.connect(
    host="localhost",
    database="musicbrainz_db",
    user="musicbrainz",
    port=5432)

cursor = conn.cursor()

# psql -h localhost -p 25432 -U musicbrainz musicbrainz_db

# engine = sql.create_engine('postgresql:///musicbrainz_db')
# connection = engine.connect()
cursor.execute("select * from recording limit 1;")
cursor.fetchone()[0]
print("connection successful")
# Out:
# connection successful

# %% [markdown]
# ### Select Random file paths

# %%
# #Load up MLHD Data Folder

# filelist = os.listdir('/data/mlhd/00')

# path = lambda name: '/data/mlhd/00/{}'.format(name)
# file_paths = [path(name) for name in filelist]

# first_10 = file_paths[:10]

# %%
# #random folder selector
# master_folder = os.listdir('/data/mlhd')
# folder_list = random.sample(master_folder, 10)

# #random file selection
# file_paths = []
# for folder in folder_list:
#     random_file = random.sample(os.listdir('/data/mlhd/'+(folder)), 1)[0]
# #     print(random_file)
#     path = '/data/mlhd/'+folder+'/'+random_file
#     file_paths.append(path)

# file_paths

# %% [markdown]
# ### Warning: Running this code-block will replace existing random file_list

# %%
# with open('random_file_paths.txt', 'w+') as f:
#     f.writelines([name+'\n' for name in file_paths])

# %% [markdown]
# ### Read frozen stored random files

# %%
with open('random_file_paths.txt', 'r') as f:
    file_paths = f.readlines()
    file_paths= [item.strip() for item in file_paths]
    
(file_paths)
# Out:
# ['/data/mlhd/07/07beee31-451d-4346-9f83-144671d68f7b.txt.gz',
#  '/data/mlhd/86/86482586-681c-43f6-8fda-05d0e5c3a5c3.txt.gz',
#  '/data/mlhd/aa/aaaec8b6-6ec5-4efa-b9ee-ee089431d9c3.txt.gz',
#  '/data/mlhd/0d/0d309017-bc04-4c2b-be84-ee01899fe087.txt.gz',
#  '/data/mlhd/b3/b3ded736-58be-45ed-a018-5803c9eae282.txt.gz',
#  '/data/mlhd/82/822abba8-6493-49ae-b70f-35f1ad8ca052.txt.gz',
#  '/data/mlhd/56/567d224e-0660-4eaf-a6f5-34f7abe7e609.txt.gz',
#  '/data/mlhd/4d/4d68890f-29d1-402d-8650-43941e1a3559.txt.gz',
#  '/data/mlhd/ad/ad2ff9c6-7c80-4835-80b4-c117de9a2c2b.txt.gz',
#  '/data/mlhd/e7/e7305d9a-260c-47b0-ba1b-01892300fa68.txt.gz']

# %%
# fetch df

# Use dask.dataframe since it's ~ 14x faster than pandas dataframe! 

def fetch_df_dd(pth):
#     df = dd.read_csv(pth, sep='\t', names=['timestamp', 'artist-MBID', 'release-MBID', 'recording-MBID'], blocksize=None)
    df = pd.read_csv(pth, sep='\t', names=['timestamp', 'artist-MBID', 'release-MBID', 'recording-MBID'])
    
    # DROPPING ALL FILES WITHOUT recording-MBID
    df = df[-df['recording-MBID'].isna()]
    return df

df = fetch_df_dd(file_paths[9])
print(len(df))
df.head()
# Out:
# 10694
#     timestamp                           artist-MBID  \
# 0  1238828757  71f17703-cd11-4579-b08a-1b1c8e6f5ac2
# 1  1238828982  71f17703-cd11-4579-b08a-1b1c8e6f5ac2
# 2  1238829203  71f17703-cd11-4579-b08a-1b1c8e6f5ac2
# 4  1239496830  0039c7ae-e1a7-4a7d-9b49-0cbc716821a6
# 5  1239497092  0039c7ae-e1a7-4a7d-9b49-0cbc716821a6
#
#                            release-MBID                        recording-MBID
# 0  15efe0ab-055a-4562-b290-be39336e49bd  986dd819-7c83-4c9e-905b-6cb65ccbea3b
# 1  15efe0ab-055a-4562-b290-be39336e49bd  52d46c9b-96f4-4e59-8216-68f8b5ee2b89
# 2  15efe0ab-055a-4562-b290-be39336e49bd  200c74aa-7d6d-4a9b-8284-35094186a00b
# 4                                   NaN  06bf6d0c-3094-492e-92fc-4867b9364d0b
# 5                                   NaN  571b7e68-b7cf-4d33-97e2-b59eb7d00b9d

# %%
# Function to yield a chunk from dataframe.

def yield_chunk(dataframe, chunksize):
    l = len(dataframe)
    if l<chunksize:
        return dataframe
    
    for i in range(chunksize,l,chunksize):
        start = i-chunksize
        yield dataframe[start:i]['recording-MBID']
        
gen = yield_chunk(df, 5)
type(next(gen))
# Out:
# pandas.core.series.Series

# %%
# A function to take single mbid as input and: 
# 1. cross check with recording table. If present, return the SAME recording-mbid from recording table.
# 2. If not in recording table, check in track table. If present, return 
# 3. If not in recording/track table, check if it exists in the recording_gid_redirect table
# 4. If not in any of the above tables, add the mbid to bad_entries list.

# Check if a recording-MBID exists in the "recording" table. If exists, return the mbid. If not, return None
def check_in_recording(rec_mbid):
    cursor.execute("SELECT gid FROM recording WHERE gid=%(id)s;", {'id':rec_mbid})
    fetch = cursor.fetchone()
    
    if type(fetch) == tuple:
        return fetch[0]
    else:
        count_not_recording.add(rec_mbid)
        return None


# If MBID in recording_gid_redirect, return the redirected MBID. Else, return None
def check_in_redirect(rec_mbid):
    cursor.execute("select r.gid from recording r join recording_gid_redirect rgr on rgr.new_id = r.id where rgr.gid = %(id)s;", {'id':rec_mbid})
    fetch = cursor.fetchone()
    
    if type(fetch) == tuple:
        return fetch[0]
    else:
        count_not_redirect.add(rec_mbid)
        return None


# Check if a recording-MBID exists in the "track" table. If not, return None. 
# If yes, append the track-mbid to the list track_mbids

track_mbids = []
def check_in_track(rec_mbid):
    cursor.execute("SELECT gid FROM track WHERE gid=%(id)s;", {'id':rec_mbid})
    fetch = cursor.fetchone()
    
    if type(fetch) == tuple:
        track_mbids.add(rec_mbid)
        return fetch[0]
    else:
        count_not_track.add(rec_mbid)
        return None

# Simple function to take single mbid as input and:
# Find its canonical MBID
def get_canon(rec_mbid):
    cursor.execute("SELECT canonical_recording_mbid FROM mapping.canonical_recording_redirect WHERE recording_mbid=%(id)s;", {'id':rec_mbid})
    if cursor.fetchone()!=None:
        count_not_canonical.add(rec_mbid)
        return cursor.fetchone()
    else:
        return rec_mbid
    
# Function to validate MBIDs and replace MBIDS through a chain of functions.
def check_validity(rec_mbid):
    x = check_in_recording(rec_mbid)
    
    if x != None:
        return x
    else:
        x = check_in_redirect(rec_mbid)
    
        if x != None:
            return x
        else:            
            x = check_in_track(rec_mbid)
            
            if x!= None:
                return x
            else:
                return None

# %%
# # query = "SELECT gid FROM track WHERE gid=%(id)s;"
# # cursor.execute(query,{'id':'625826fb-1380-4a0a-8b2a-03690e043c25'})


# tup = ('0f42ab32-22cd-4dcf-927b-a8d9a183d68b','327c8bf3-809b-4368-b590-7867a6cc805a')

# print(str(tup))
# query = '''SELECT id FROM recording 
# WHERE gid in ('0f42ab32-22cd-4dcf-927b-a8d9a183d68b','327c8bf3-809b-4368-b590-7867a6cc805a');'''
# cursor.execute(query)
# print(cursor.fetchall())

# %%
rec = df['recording-MBID']
print(rec)
# print(check_in_recording(rec))
# # cursor.execute("select * from recording limit 1;")
# Out:
# 0        986dd819-7c83-4c9e-905b-6cb65ccbea3b
# 1        52d46c9b-96f4-4e59-8216-68f8b5ee2b89
# 2        200c74aa-7d6d-4a9b-8284-35094186a00b
# 4        06bf6d0c-3094-492e-92fc-4867b9364d0b
# 5        571b7e68-b7cf-4d33-97e2-b59eb7d00b9d
#                          ...
# 13354    4c3b6406-e144-434f-baab-372577764dbe
# 13355    5f27596a-3bd0-45b0-bd7e-d75ffc2674b0
# 13356    06fe79c6-f43f-46fd-acea-c3df21bb07a6
# 13357    fc8df6e8-8184-47b7-a9db-a36d53d0ea21
# 13358    c7bb57ec-3559-49e7-82a4-071f895b6190
# Name: recording-MBID, Length: 10694, dtype: object

# %%
# Declaring count sets
count_not_recording, count_not_redirect, count_not_track, count_misc, count_not_canonical = set(), set(), set(), set(), set()

# Driver function to check validity and get canononical MBID.
def driver_function(rec_mbid):
    x = check_validity(rec_mbid)
    # check_validity checks MBIDs in the following order: is recording-MBID? -> is redirectable-MBID? -> is track-MBID?
    # If its not either of the above 3, None is returned.
    
    if x != None:
        return get_canon(rec_mbid)
    # If its not None, find its canonical-MBID
    else:
        return None

# %%
# %%time
# df2 = df['recording-MBID'].map(driver_function, meta=('x', str)).compute()
df2 = df['recording-MBID'].map(driver_function)
# track_mbids
# Out:
# CPU times: user 865 ms, sys: 981 ms, total: 1.85 s
# Wall time: 19.6 s

# %%
x = (("total rows in dataset", len(df2))
,("time taken", "0min 19.6s")
,("number of Null values in appended to the dataset", df2.isna().sum())
,("number of values not present in the table 'recording'",len(count_not_recording))
,("number of values not present niether in the table 'recording' nor in 'redirect'",len(count_not_redirect))
,("num of values niether in recording, nor redirect, nor track",len(count_not_track))
,("number of track-MBIDs in the recording-MBID column",len(track_mbids))
,("num of broken MBIDs =", len(count_not_redirect.intersection(count_not_track)))
,("num of non-canonical IDs found in recording-mbid table", len(count_not_canonical)))

results.append(dict(x))

# %%
results
# Out:
# [{'total rows in dataset': 102752,
#   'time taken': '2min',
#   'number of Null values in appended to the dataset': 25591,
#   "number of values not present in the table 'recording'": 2147,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 56,
#   'num of values niether in recording, nor redirect, nor track': 56,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 56,
#   'num of non-canonical IDs found in recording-mbid table': 1568},
#  {'total rows in dataset': 20652,
#   'time taken': '12.4s',
#   'number of Null values in appended to the dataset': 6048,
#   "number of values not present in the table 'recording'": 1873,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 23,
#   'num of values niether in recording, nor redirect, nor track': 23,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 23,
#   'num of non-canonical IDs found in recording-mbid table': 1392},
#  {'total rows in dataset': 22931,
#   'time taken': '2min 48s',
#   'number of Null values in appended to the dataset': 7473,
#   "number of values not present in the table 'recording'": 2496,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 16,
#   'num of values niether in recording, nor redirect, nor track': 16,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 16,
#   'num of non-canonical IDs found in recording-mbid table': 2706},
#  {'total rows in dataset': 23309,
#   'time taken': '1min 19s',
#   'number of Null values in appended to the dataset': 7546,
#   "number of values not present in the table 'recording'": 1429,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 16,
#   'num of values niether in recording, nor redirect, nor track': 16,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 16,
#   'num of non-canonical IDs found in recording-mbid table': 1867},
#  {'total rows in dataset': 75334,
#   'time taken': '3min 20s',
#   'number of Null values in appended to the dataset': 19293,
#   "number of values not present in the table 'recording'": 2672,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 53,
#   'num of values niether in recording, nor redirect, nor track': 53,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 53,
#   'num of non-canonical IDs found in recording-mbid table': 4057},
#  {'total rows in dataset': 60944,
#   'time taken': '1min 54s',
#   'number of Null values in appended to the dataset': 20462,
#   "number of values not present in the table 'recording'": 2982,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 17,
#   'num of values niether in recording, nor redirect, nor track': 17,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 17,
#   'num of non-canonical IDs found in recording-mbid table': 4009},
#  {'total rows in dataset': 9327,
#   'time taken': '0min 14s',
#   'number of Null values in appended to the dataset': 2145,
#   "number of values not present in the table 'recording'": 389,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 1,
#   'num of values niether in recording, nor redirect, nor track': 1,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 1,
#   'num of non-canonical IDs found in recording-mbid table': 261},
#  {'total rows in dataset': 47740,
#   'time taken': '1min 33s',
#   'number of Null values in appended to the dataset': 15228,
#   "number of values not present in the table 'recording'": 2761,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 13,
#   'num of values niether in recording, nor redirect, nor track': 13,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 13,
#   'num of non-canonical IDs found in recording-mbid table': 3023},
#  {'total rows in dataset': 8991,
#   'time taken': '0min 18.4s',
#   'number of Null values in appended to the dataset': 2331,
#   "number of values not present in the table 'recording'": 642,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 7,
#   'num of values niether in recording, nor redirect, nor track': 7,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 7,
#   'num of non-canonical IDs found in recording-mbid table': 571},
#  {'total rows in dataset': 10694,
#   'time taken': '0min 19.6s',
#   'number of Null values in appended to the dataset': 2450,
#   "number of values not present in the table 'recording'": 827,
#   "number of values not present niether in the table 'recording' nor in 'redirect'": 6,
#   'num of values niether in recording, nor redirect, nor track': 6,
#   'number of track-MBIDs in the recording-MBID column': 0,
#   'num of broken MBIDs =': 6,
#   'num of non-canonical IDs found in recording-mbid table': 886}]

# %%
results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#    total rows in dataset  time taken  \
# 0                 102752        2min
# 1                  20652       12.4s
# 2                  22931    2min 48s
# 3                  23309    1min 19s
# 4                  75334    3min 20s
# 5                  60944    1min 54s
# 6                   9327    0min 14s
# 7                  47740    1min 33s
# 8                   8991  0min 18.4s
# 9                  10694  0min 19.6s
#
#    number of Null values in appended to the dataset  \
# 0                                             25591
# 1                                              6048
# 2                                              7473
# 3                                              7546
# 4                                             19293
# 5                                             20462
# 6                                              2145
# 7                                             15228
# 8                                              2331
# 9                                              2450
#
#    number of values not present in the table 'recording'  \
# 0                                               2147
# 1                                               1873
# 2                                               2496
# 3                                               1429
# 4                                               2672
# 5                                               2982
# 6                                                389
# 7                                               2761
# 8                                                642
# 9                                                827
#
#    number of values not present niether in the table 'recording' nor in 'redirect'  \
# 0                                                 56
# 1                                                 23
# 2                                                 16
# 3                                                 16
# 4                                                 53
# 5                                                 17
# 6                                                  1
# 7                                                 13
# 8                                                  7
# 9                                                  6
#
#    num of values niether in recording, nor redirect, nor track  \
# 0                                                 56
# 1                                                 23
# 2                                                 16
# 3                                                 16
# 4                                                 53
# 5                                                 17
# 6                                                  1
# 7                                                 13
# 8                                                  7
# 9                                                  6
#
#    number of track-MBIDs in the recording-MBID column  num of broken MBIDs =  \
# 0                                                  0                      56
# 1                                                  0                      23
# 2                                                  0                      16
# 3                                                  0                      16
# 4                                                  0                      53
# 5                                                  0                      17
# 6                                                  0                       1
# 7                                                  0                      13
# 8                                                  0                       7
# 9                                                  0                       6
#
#    num of non-canonical IDs found in recording-mbid table
# 0                                               1568
# 1                                               1392
# 2                                               2706
# 3                                               1867
# 4                                               4057
# 5                                               4009
# 6                                                261
# 7                                               3023
# 8                                                571
# 9                                                886

# %%
results_df.to_csv("random-10-results.csv", encoding='utf-8')

# %%
results_df['seconds_taken'] = pd.Series([120, 12.4, 168, 200, 114, 14, 93, 18.4, 19,6])
results_df['average_time_per_10k'] = (results_df['seconds_taken']/results_df.iloc[:,0])*10000
results_df
# Out:
#    total rows in dataset  time taken  \
# 0                 102752        2min
# 1                  20652       12.4s
# 2                  22931    2min 48s
# 3                  23309    1min 19s
# 4                  75334    3min 20s
# 5                  60944    1min 54s
# 6                   9327    0min 14s
# 7                  47740    1min 33s
# 8                   8991  0min 18.4s
# 9                  10694  0min 19.6s
#
#    number of Null values in appended to the dataset  \
# 0                                             25591
# 1                                              6048
# 2                                              7473
# 3                                              7546
# 4                                             19293
# 5                                             20462
# 6                                              2145
# 7                                             15228
# 8                                              2331
# 9                                              2450
#
#    number of values not present in the table 'recording'  \
# 0                                               2147
# 1                                               1873
# 2                                               2496
# 3                                               1429
# 4                                               2672
# 5                                               2982
# 6                                                389
# 7                                               2761
# 8                                                642
# 9                                                827
#
#    number of values not present niether in the table 'recording' nor in 'redirect'  \
# 0                                                 56
# 1                                                 23
# 2                                                 16
# 3                                                 16
# 4                                                 53
# 5                                                 17
# 6                                                  1
# 7                                                 13
# 8                                                  7
# 9                                                  6
#
#    num of values niether in recording, nor redirect, nor track  \
# 0                                                 56
# 1                                                 23
# 2                                                 16
# 3                                                 16
# 4                                                 53
# 5                                                 17
# 6                                                  1
# 7                                                 13
# 8                                                  7
# 9                                                  6
#
#    number of track-MBIDs in the recording-MBID column  num of broken MBIDs =  \
# 0                                                  0                      56
# 1                                                  0                      23
# 2                                                  0                      16
# 3                                                  0                      16
# 4                                                  0                      53
# 5                                                  0                      17
# 6                                                  0                       1
# 7                                                  0                      13
# 8                                                  0                       7
# 9                                                  0                       6
#
#    num of non-canonical IDs found in recording-mbid table  seconds_taken  \
# 0                                               1568               120.0
# 1                                               1392                12.4
# 2                                               2706               168.0
# 3                                               1867               200.0
# 4                                               4057               114.0
# 5                                               4009                14.0
# 6                                                261                93.0
# 7                                               3023                18.4
# 8                                                571                19.0
# 9                                                886                 6.0
#
#    average_time_per_10k
# 0             11.678605
# 1              6.004261
# 2             73.263268
# 3             85.803767
# 4             15.132609
# 5              2.297191
# 6             99.710518
# 7              3.854210
# 8             21.132243
# 9              5.610623

# %%
results_df2 = results_df.copy()
results_df2.drop(['time taken'], axis=1, inplace=True)
results_df2.iloc[:, 1:9].apply(lambda x: x/100)
for i in range(len(results_df2)):
    results_df2.iloc[i, 1:9] = results_df2.iloc[i, 1:9].apply(lambda x: x*100/results_df2.iloc[i,0])

results_df2
# The values below are in percent. (unless specified in the column)
# Out:
#    total rows in dataset  number of Null values in appended to the dataset  \
# 0                 102752                                         24.905598
# 1                  20652                                         29.285299
# 2                  22931                                         32.589072
# 3                  23309                                         32.373761
# 4                  75334                                         25.609950
# 5                  60944                                         33.575085
# 6                   9327                                         22.997748
# 7                  47740                                         31.897780
# 8                   8991                                         25.925926
# 9                  10694                                         22.910043
#
#    number of values not present in the table 'recording'  \
# 0                                           2.089497
# 1                                           9.069340
# 2                                          10.884828
# 3                                           6.130679
# 4                                           3.546871
# 5                                           4.893017
# 6                                           4.170687
# 7                                           5.783410
# 8                                           7.140474
# 9                                           7.733308
#
#    number of values not present niether in the table 'recording' nor in 'redirect'  \
# 0                                           0.054500
# 1                                           0.111369
# 2                                           0.069775
# 3                                           0.068643
# 4                                           0.070353
# 5                                           0.027894
# 6                                           0.010722
# 7                                           0.027231
# 8                                           0.077856
# 9                                           0.056106
#
#    num of values niether in recording, nor redirect, nor track  \
# 0                                           0.054500
# 1                                           0.111369
# 2                                           0.069775
# 3                                           0.068643
# 4                                           0.070353
# 5                                           0.027894
# 6                                           0.010722
# 7                                           0.027231
# 8                                           0.077856
# 9                                           0.056106
#
#    number of track-MBIDs in the recording-MBID column  num of broken MBIDs =  \
# 0                                                  0                0.054500
# 1                                                  0                0.111369
# 2                                                  0                0.069775
# 3                                                  0                0.068643
# 4                                                  0                0.070353
# 5                                                  0                0.027894
# 6                                                  0                0.010722
# 7                                                  0                0.027231
# 8                                                  0                0.077856
# 9                                                  0                0.056106
#
#    num of non-canonical IDs found in recording-mbid table  seconds_taken  \
# 0                                           1.526004            0.116786
# 1                                           6.740267            0.060043
# 2                                          11.800619            0.732633
# 3                                           8.009782            0.858038
# 4                                           5.385351            0.151326
# 5                                           6.578170            0.022972
# 6                                           2.798327            0.997105
# 7                                           6.332216            0.038542
# 8                                           6.350795            0.211322
# 9                                           8.285020            0.056106
#
#    average_time_per_10k
# 0             11.678605
# 1              6.004261
# 2             73.263268
# 3             85.803767
# 4             15.132609
# 5              2.297191
# 6             99.710518
# 7              3.854210
# 8             21.132243
# 9              5.610623

# %%
results_df2.describe()
# Out:
#        total rows in dataset  \
# count              10.000000
# mean            38267.400000
# std             32249.655916
# min              8991.000000
# 25%             13183.500000
# 50%             23120.000000
# 75%             57643.000000
# max            102752.000000
#
#        number of Null values in appended to the dataset  \
# count                                         10.000000
# mean                                          28.207026
# std                                            4.192674
# min                                           22.910043
# 25%                                           25.081686
# 50%                                           27.605613
# 75%                                           32.254766
# max                                           33.575085
#
#        number of values not present in the table 'recording'  \
# count                                          10.000000
# mean                                            6.144211
# std                                             2.652569
# min                                             2.089497
# 25%                                             4.351270
# 50%                                             5.957045
# 75%                                             7.585100
# max                                            10.884828
#
#        number of values not present niether in the table 'recording' nor in 'redirect'  \
# count                                          10.000000
# mean                                            0.057445
# std                                             0.029341
# min                                             0.010722
# 25%                                             0.034546
# 50%                                             0.062375
# 75%                                             0.070209
# max                                             0.111369
#
#        num of values niether in recording, nor redirect, nor track  \
# count                                          10.000000
# mean                                            0.057445
# std                                             0.029341
# min                                             0.010722
# 25%                                             0.034546
# 50%                                             0.062375
# 75%                                             0.070209
# max                                             0.111369
#
#        number of track-MBIDs in the recording-MBID column  \
# count                                               10.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        num of broken MBIDs =  \
# count              10.000000
# mean                0.057445
# std                 0.029341
# min                 0.010722
# 25%                 0.034546
# 50%                 0.062375
# 75%                 0.070209
# max                 0.111369
#
#        num of non-canonical IDs found in recording-mbid table  seconds_taken  \
# count                                          10.000000           10.000000
# mean                                            6.380655            0.324487
# std                                             2.852281            0.380678
# min                                             1.526004            0.022972
# 25%                                             5.622067            0.057090
# 50%                                             6.464483            0.134056
# 75%                                             7.692403            0.602305
# max                                            11.800619            0.997105
#
#        average_time_per_10k
# count             10.000000
# mean              32.448730
# std               38.067775
# min                2.297191
# 25%                5.709032
# 50%               13.405607
# 75%               60.230512
# max               99.710518

# %% [markdown]
# # Report
#
# ## Methodology:
# - Selected 10 random folders from the first 256 folders in the MLHD dataset. (That's all that I had on wolf)
# - Selected 1 random file from each random folder
# - The randomly selected files have been frozen in a text file for test reproducability.
# - Some computations have been run on each of the 10 random files to check the number of bad items.
#
# ## Reports
# Check the above table to find percent of values as specified in the column.
#
# ### Interesting Observations (mean):
# - Only 6% of the values weren't present in the recording table on SQL.
#     - i.e. 94% recording-MBIDs are completely valid
# - 0.05% of the recording-MBIDs were neither recording-MBIDs, nor redirectable-MBIDs, nor track-MBIDs
# - 0% of the recording-MBIDs were track-MBIDs
# - 6% of the recording-MBIDs (after checking if they were redirectable-MBIDs or track-MBIDs) were non-canonical, and a canonical-MBID was found for them.
# - 28% values appended were null (I don't even know what it means at this point)
#
# - With the current algorithm, it took on average 32 seconds per 10k rows.
#     - This time however varies wildly due to caching (38 seconds standard deviation)
#     - Min time taken per 10k rows: 2s
#     - Max time taken per 10k rows: 99s
